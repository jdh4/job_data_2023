# %% [markdown]
# # Cleaning sacct data for Stellar

# %% [markdown]
# <pre>$ ssh tiger
# $ export SLURM_TIME_FORMAT="%s"
# $ sacct -M tiger2 -a -X -P -S 2023-01-01T00:00:00 -E 2023-12-31T23:59:59 -o cluster,start,end,elapsedraw,timelimitraw,ncpus,nnodes,cputimeraw,alloctres,nodelist,admincomment > tiger.2023</pre>

# %% [markdown]
# ## Working directory

# %% [markdown]
# On della, see /home/jdh4/wentzlaff_job_data_2023

# %% [markdown]
# ## Cleaning

# %%
import os
import re
import subprocess
import numpy as np
import pandas as pd
from efficiency import get_stats_dict
from efficiency import cpu_efficiency
from efficiency import gpu_efficiency
from efficiency import cpu_memory_usage
from efficiency import gpu_memory_usage_eff_tuples

# %%
df = pd.read_csv("tiger.2023", sep="|")
df.head(2).T
# Out:
#                                                               0  \
# Cluster                                                  tiger2
# Start                                              1672344064.0
# End                                                  1672581955
# ElapsedRaw                                               237891
# TimelimitRaw                                               4260
# NCPUS                                                         2
# NNodes                                                        1
# CPUTimeRAW                                               475782
# AllocTRES                      billing=25,cpu=2,mem=120G,node=1
# NodeList                                          tiger-i26c2n9
# AdminComment  JS1:H4sIAEmTsWMC/1WNQQrCMBBF7zLrKMnMmE5yGZF2KA...
#
#                                                               1
# Cluster                                                  tiger2
# Start                                              1672356142.0
# End                                                  1672576343
# ElapsedRaw                                               220201
# TimelimitRaw                                               4260
# NCPUS                                                         2
# NNodes                                                        1
# CPUTimeRAW                                               440402
# AllocTRES                      billing=21,cpu=2,mem=100G,node=1
# NodeList                                         tiger-i26c2n10
# AdminComment  JS1:H4sIAF19sWMC/1WN0QqDMBAE/+We07J3nprmZ0rRQw...

# %%
df.columns = [col.lower() for col in df.columns]

# %%
renamings = {"user":"netid",
             "cputimeraw":"cpu-seconds",
             "nnodes":"nodes",
             "ncpus":"cores",
             "timelimitraw":"limit-minutes"}
df.rename(columns=renamings, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857281 entries, 0 to 857280
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   cluster        857281 non-null  object
#  1   start          804992 non-null  float64
#  2   end            857281 non-null  int64
#  3   elapsedraw     857281 non-null  int64
#  4   limit-minutes  857281 non-null  int64
#  5   cores          857281 non-null  int64
#  6   nodes          857281 non-null  int64
#  7   cpu-seconds    857281 non-null  int64
#  8   alloctres      804754 non-null  object
#  9   nodelist       857281 non-null  object
#  10  admincomment   804973 non-null  object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 71.9+ MB

# %%
if df["elapsedraw"].dtype == 'object':
    # clean elapsedraw field
    df = df[pd.notna(df.elapsedraw)]
    df = df[df.elapsedraw.str.isnumeric()]
df.elapsedraw = df.elapsedraw.astype("int64")
df = df[df.elapsedraw > 0]

# %%
if df["start"].dtype == 'object':
    # clean start field
    df = df[pd.notna(df.start)]
    df = df[df.start.str.isnumeric()]
df.start = df.start.astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 765425 entries, 0 to 857280
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   cluster        765425 non-null  object
#  1   start          765425 non-null  int64
#  2   end            765425 non-null  int64
#  3   elapsedraw     765425 non-null  int64
#  4   limit-minutes  765425 non-null  int64
#  5   cores          765425 non-null  int64
#  6   nodes          765425 non-null  int64
#  7   cpu-seconds    765425 non-null  int64
#  8   alloctres      765425 non-null  object
#  9   nodelist       765425 non-null  object
#  10  admincomment   765406 non-null  object
# dtypes: int64(7), object(4)
# memory usage: 70.1+ MB

# %%
def gpus_per_job(tres: str) -> int:
    """Return the number of allocated GPUs."""
    gpus = re.findall(r"gres/gpu=\d+", tres)
    return int(gpus[0].replace("gres/gpu=", "")) if gpus else 0

# %%
df["gpus"] = df.alloctres.apply(gpus_per_job)
df["gpu-seconds"] = df.apply(lambda row: row["elapsedraw"] * row["gpus"], axis='columns')

# %%
df["admincomment"] = df["admincomment"].apply(get_stats_dict)

# %% [markdown]
# ## CPU and GPU efficiency

# %%
df["jobid"] = -1

# %%
df["cpu-eff-tuple"] = df.apply(lambda row: cpu_efficiency(row["admincomment"],
                                                          row["elapsedraw"],
                                                          row["jobid"],
                                                          row["cluster"],
                                                          single=True),
                                                          axis="columns")

# %%
def clean_eff_tuple(tpl):
    eff, error_code = tpl
    if error_code:
        return np.nan
    else:
        return eff

# %%
df["cpu-eff"] = df["cpu-eff-tuple"].apply(clean_eff_tuple)

# %%
df["gpu-eff-tuple"] = df.apply(lambda row: gpu_efficiency(row["admincomment"],
                                                          row["elapsedraw"],
                                                          row["jobid"],
                                                          row["cluster"],
                                                          single=True,
                                                          verbose=False),
                                                          axis="columns")

# %%
df["gpu-eff"] = df["gpu-eff-tuple"].apply(clean_eff_tuple)

# %%
df.head(2).T
# Out:
#                                                                0  \
# cluster                                                   tiger2
# start                                                 1672344064
# end                                                   1672581955
# elapsedraw                                                237891
# limit-minutes                                               4260
# cores                                                          2
# nodes                                                          1
# cpu-seconds                                               475782
# alloctres                       billing=25,cpu=2,mem=120G,node=1
# nodelist                                           tiger-i26c2n9
# admincomment   {'nodes': {'tiger-i26c2n9': {'total_memory': 1...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (96.1, 0)
# cpu-eff                                                     96.1
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
#
#                                                                1
# cluster                                                   tiger2
# start                                                 1672356142
# end                                                   1672576343
# elapsedraw                                                220201
# limit-minutes                                               4260
# cores                                                          2
# nodes                                                          1
# cpu-seconds                                               440402
# alloctres                       billing=21,cpu=2,mem=100G,node=1
# nodelist                                          tiger-i26c2n10
# admincomment   {'nodes': {'tiger-i26c2n10': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (94.2, 0)
# cpu-eff                                                     94.2
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN

# %%
df[["nodes", "cores", "gpus", "cpu-eff", "gpu-eff"]].describe()
# Out:
#                nodes          cores           gpus        cpu-eff      gpu-eff
# count  765425.000000  765425.000000  765425.000000  341293.000000  1203.000000
# mean        1.890835      42.144943       0.034578      61.636323    81.481712
# std         3.767816     157.497636       0.905928      34.405438    11.100336
# min         1.000000       1.000000       0.000000       0.000000     0.000000
# 25%         1.000000       1.000000       0.000000      30.000000    80.300000
# 50%         1.000000       1.000000       0.000000      69.500000    86.600000
# 75%         1.000000       4.000000       0.000000      94.700000    87.200000
# max       128.000000    5120.000000      24.000000      99.900000    95.200000

# %% [markdown]
# ## CPU and GPU memory

# %%
df["cpu-mem-tuple"] = df.apply(lambda row: cpu_memory_usage(row["admincomment"],
                                                            row["jobid"],
                                                            row["cluster"],
                                                            verbose=False),
                                                            axis="columns")

# %%
df["gpu-mem-tuple"] = df.apply(lambda row: gpu_memory_usage_eff_tuples(row["admincomment"],
                                                                       row["jobid"],
                                                                       row["cluster"],
                                                                       verbose=False),
                                                                       axis="columns")

# %%
def cpu_mem_util(tpl):
    used, alloc, err = tpl
    if err or alloc == 0:
        return np.nan
    util = round(100 * used / alloc)
    if util > 100:
        return np.nan
    return util


def cpu_mem_alloc(tpl):
    used, alloc, err = tpl
    if err:
        return np.nan
    return alloc

def gpu_mem_util(tpl):
    gpus, err = tpl
    if err:
        return np.nan
    used = 0
    alloc = 0
    for gpu in gpus:
        used += gpu[0]
        alloc += gpu[1]
    return round(100 * used / alloc)

# %%
df["cpu-mem-util"] = df["cpu-mem-tuple"].apply(cpu_mem_util)
df["cpu-mem-alloc"] = df["cpu-mem-tuple"].apply(cpu_mem_alloc)
df["gpu-mem-util"] = df["gpu-mem-tuple"].apply(gpu_mem_util)

# %%
df.head(15).T
# Out:
#                                                               0   \
# cluster                                                   tiger2
# start                                                 1672344064
# end                                                   1672581955
# elapsedraw                                                237891
# limit-minutes                                               4260
# cores                                                          2
# nodes                                                          1
# cpu-seconds                                               475782
# alloctres                       billing=25,cpu=2,mem=120G,node=1
# nodelist                                           tiger-i26c2n9
# admincomment   {'nodes': {'tiger-i26c2n9': {'total_memory': 1...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (96.1, 0)
# cpu-eff                                                     96.1
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (82.0, 120.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                68.0
# cpu-mem-alloc                                              120.0
# gpu-mem-util                                                 NaN
#
#                                                               1   \
# cluster                                                   tiger2
# start                                                 1672356142
# end                                                   1672576343
# elapsedraw                                                220201
# limit-minutes                                               4260
# cores                                                          2
# nodes                                                          1
# cpu-seconds                                               440402
# alloctres                       billing=21,cpu=2,mem=100G,node=1
# nodelist                                          tiger-i26c2n10
# admincomment   {'nodes': {'tiger-i26c2n10': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (94.2, 0)
# cpu-eff                                                     94.2
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (82.0, 100.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                82.0
# cpu-mem-alloc                                              100.0
# gpu-mem-util                                                 NaN
#
#                                                               2   \
# cluster                                                   tiger2
# start                                                 1672336647
# end                                                   1672853505
# elapsedraw                                                516858
# limit-minutes                                               8640
# cores                                                        800
# nodes                                                         20
# cpu-seconds                                            413486400
# alloctres                  billing=800,cpu=800,mem=3125G,node=20
# nodelist       tiger-h19c2n[20-23],tiger-h20c1n[9-16],tiger-h...
# admincomment   {'nodes': {'tiger-h19c2n20': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.7, 0)
# cpu-eff                                                     99.7
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                  (64.0, 3125.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                 2.0
# cpu-mem-alloc                                             3125.0
# gpu-mem-util                                                 NaN
#
#                                                               3   \
# cluster                                                   tiger2
# start                                                 1672444889
# end                                                   1672703796
# elapsedraw                                                258907
# limit-minutes                                               4310
# cores                                                          2
# nodes                                                          1
# cpu-seconds                                               517814
# alloctres                       billing=21,cpu=2,mem=100G,node=1
# nodelist                                           tiger-h20c1n4
# admincomment   {'nodes': {'tiger-h20c1n4': {'total_memory': 1...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (93.2, 0)
# cpu-eff                                                     93.2
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (82.0, 100.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                82.0
# cpu-mem-alloc                                              100.0
# gpu-mem-util                                                 NaN
#
#                                                               4   \
# cluster                                                   tiger2
# start                                                 1672316882
# end                                                   1672608746
# elapsedraw                                                291864
# limit-minutes                                               6719
# cores                                                          2
# nodes                                                          1
# cpu-seconds                                               583728
# alloctres                       billing=25,cpu=2,mem=120G,node=1
# nodelist                                          tiger-i26c2n13
# admincomment   {'nodes': {'tiger-i26c2n13': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (94.5, 0)
# cpu-eff                                                     94.5
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (96.0, 120.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                80.0
# cpu-mem-alloc                                              120.0
# gpu-mem-util                                                 NaN
#
#                                                               5   \
# cluster                                                   tiger2
# start                                                 1672318017
# end                                                   1672642893
# elapsedraw                                                324876
# limit-minutes                                               6719
# cores                                                          2
# nodes                                                          1
# cpu-seconds                                               649752
# alloctres                       billing=25,cpu=2,mem=120G,node=1
# nodelist                                          tiger-h22c1n16
# admincomment   {'nodes': {'tiger-h22c1n16': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (94.5, 0)
# cpu-eff                                                     94.5
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (96.0, 120.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                80.0
# cpu-mem-alloc                                              120.0
# gpu-mem-util                                                 NaN
#
#                                                               6   \
# cluster                                                   tiger2
# start                                                 1672467126
# end                                                   1672567561
# elapsedraw                                                100435
# limit-minutes                                               4260
# cores                                                          4
# nodes                                                          1
# cpu-seconds                                               401740
# alloctres                       billing=46,cpu=4,mem=220G,node=1
# nodelist                                          tiger-h19c2n14
# admincomment   {'nodes': {'tiger-h19c2n14': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (98.3, 0)
# cpu-eff                                                     98.3
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                  (201.0, 220.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                91.0
# cpu-mem-alloc                                              220.0
# gpu-mem-util                                                 NaN
#
#                                                               7   \
# cluster                                                   tiger2
# start                                                 1672336697
# end                                                   1672590507
# elapsedraw                                                253810
# limit-minutes                                               4320
# cores                                                        120
# nodes                                                          3
# cpu-seconds                                             30457200
# alloctres                 billing=120,cpu=120,mem=480000M,node=3
# nodelist                                       tiger-h26c1n[7-9]
# admincomment   {'nodes': {'tiger-h26c1n7': {'total_memory': 1...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.7, 0)
# cpu-eff                                                     99.7
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (70.0, 469.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                15.0
# cpu-mem-alloc                                              469.0
# gpu-mem-util                                                 NaN
#
#                                                               8   \
# cluster                                                   tiger2
# start                                                 1672336704
# end                                                   1672581101
# elapsedraw                                                244397
# limit-minutes                                               4320
# cores                                                        120
# nodes                                                          3
# cpu-seconds                                             29327640
# alloctres                 billing=120,cpu=120,mem=480000M,node=3
# nodelist                                     tiger-h26c1n[12-14]
# admincomment   {'nodes': {'tiger-h26c1n12': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.7, 0)
# cpu-eff                                                     99.7
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (70.0, 469.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                15.0
# cpu-mem-alloc                                              469.0
# gpu-mem-util                                                 NaN
#
#                                                               9   \
# cluster                                                   tiger2
# start                                                 1672336707
# end                                                   1672577127
# elapsedraw                                                240420
# limit-minutes                                               4320
# cores                                                        120
# nodes                                                          3
# cpu-seconds                                             28850400
# alloctres                 billing=120,cpu=120,mem=480000M,node=3
# nodelist                                     tiger-h26c2n[10-12]
# admincomment   {'nodes': {'tiger-h26c2n10': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.7, 0)
# cpu-eff                                                     99.7
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (70.0, 469.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                15.0
# cpu-mem-alloc                                              469.0
# gpu-mem-util                                                 NaN
#
#                                                               10  \
# cluster                                                   tiger2
# start                                                 1672345072
# end                                                   1672585663
# elapsedraw                                                240591
# limit-minutes                                               4320
# cores                                                        120
# nodes                                                          3
# cpu-seconds                                             28870920
# alloctres                 billing=120,cpu=120,mem=480000M,node=3
# nodelist             tiger-h19c1n7,tiger-h19c2n16,tiger-h24c2n23
# admincomment   {'nodes': {'tiger-h19c1n7': {'total_memory': 1...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.7, 0)
# cpu-eff                                                     99.7
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (70.0, 469.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                15.0
# cpu-mem-alloc                                              469.0
# gpu-mem-util                                                 NaN
#
#                                                               11  \
# cluster                                                   tiger2
# start                                                 1672345440
# end                                                   1672584957
# elapsedraw                                                239517
# limit-minutes                                               4320
# cores                                                        120
# nodes                                                          3
# cpu-seconds                                             28742040
# alloctres                 billing=120,cpu=120,mem=480000M,node=3
# nodelist                                       tiger-h25c1n[1-3]
# admincomment   {'nodes': {'tiger-h25c1n1': {'total_memory': 1...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.7, 0)
# cpu-eff                                                     99.7
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (70.0, 469.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                15.0
# cpu-mem-alloc                                              469.0
# gpu-mem-util                                                 NaN
#
#                                                               12  \
# cluster                                                   tiger2
# start                                                 1672347997
# end                                                   1672604244
# elapsedraw                                                256247
# limit-minutes                                               4320
# cores                                                        120
# nodes                                                          3
# cpu-seconds                                             30749640
# alloctres                 billing=120,cpu=120,mem=480000M,node=3
# nodelist             tiger-h25c1n4,tiger-h26c1n11,tiger-h26c2n24
# admincomment   {'nodes': {'tiger-h25c1n4': {'total_memory': 1...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.7, 0)
# cpu-eff                                                     99.7
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (69.0, 469.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                15.0
# cpu-mem-alloc                                              469.0
# gpu-mem-util                                                 NaN
#
#                                                               13  \
# cluster                                                   tiger2
# start                                                 1672350191
# end                                                   1672592271
# elapsedraw                                                242080
# limit-minutes                                               4320
# cores                                                        120
# nodes                                                          3
# cpu-seconds                                             29049600
# alloctres                 billing=120,cpu=120,mem=480000M,node=3
# nodelist                                     tiger-h20c1n[19-21]
# admincomment   {'nodes': {'tiger-h20c1n19': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.7, 0)
# cpu-eff                                                     99.7
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (70.0, 469.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                15.0
# cpu-mem-alloc                                              469.0
# gpu-mem-util                                                 NaN
#
#                                                               14
# cluster                                                   tiger2
# start                                                 1672350191
# end                                                   1672587692
# elapsedraw                                                237501
# limit-minutes                                               4320
# cores                                                        120
# nodes                                                          3
# cpu-seconds                                             28500120
# alloctres                 billing=120,cpu=120,mem=480000M,node=3
# nodelist                                     tiger-h24c2n[12-14]
# admincomment   {'nodes': {'tiger-h24c2n12': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.7, 0)
# cpu-eff                                                     99.7
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (70.0, 469.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                15.0
# cpu-mem-alloc                                              469.0
# gpu-mem-util                                                 NaN

# %%
 df[["cpu-eff",  "cpu-mem-util", "cpu-mem-alloc", "gpus", "gpu-seconds", "gpu-eff", "gpu-mem-util"]].describe()
# Out:
#              cpu-eff   cpu-mem-util  cpu-mem-alloc           gpus  \
# count  341293.000000  341230.000000  341293.000000  765425.000000
# mean       61.636323      15.667145     334.398880       0.034578
# std        34.405438      22.370998     870.406122       0.905928
# min         0.000000       0.000000       0.000000       0.000000
# 25%        30.000000       0.000000      16.000000       0.000000
# 50%        69.500000       6.000000      16.000000       0.000000
# 75%        94.700000      16.000000     128.000000       0.000000
# max        99.900000     100.000000   19200.000000      24.000000
#
#          gpu-seconds      gpu-eff  gpu-mem-util
# count  765425.000000  1203.000000   1203.000000
# mean       40.134958    81.481712     17.940981
# std      2231.380164    11.100336     10.184439
# min         0.000000     0.000000      0.000000
# 25%         0.000000    80.300000      7.000000
# 50%         0.000000    86.600000     27.000000
# 75%         0.000000    87.200000     27.000000
# max    346896.000000    95.200000     30.000000

# %%
df["cpu-seconds"].sum() / 3600
# Out:
# 119795110.50055556

# %%
df["gpu-seconds"].sum() / 3600
# Out:
# 8533.416666666666

# %% [markdown]
# ## Node type

# %%
def expand_nodelist(nodes: int, nodelist: str) -> list:
    """Convert a nodelist from sacct to a Python list of node names. For
       example: della-l07g[4-7],della-l08g2 becomes
       ['della-l07g4', 'della-l07g5', 'della-l07g6', 'della-l07g7', 'della-l08g2']
    """
    if nodes == 1:
        return [nodelist]
    cmd = f"scontrol show hostname {nodelist}"
    try:
        output = subprocess.run(cmd,
                                stdout=subprocess.PIPE,
                                shell=True,
                                timeout=5,
                                text=True,
                                check=True)
    except:
        print(f"Failed to get nodes for {nodelist}")
    else:
        return output.stdout.strip().split("\n")

# %%
df["nodelist-expanded"] = df.apply(lambda row: expand_nodelist(row["nodes"], row["nodelist"]), axis="columns")

# %%
p100 =  [f"tiger-i19g{j}" for j in range(1, 17)]
p100 = set(p100)

# %%
print(len(p100))
# Out:
# 16

# %%
def node_type(nodelist, gpus, jobid):
    if gpus > 0:
        return "gpu"
    else:
        sub = set(nodelist) - p100
        if len(sub) < len(nodelist):
            # check for cpu nodes being used for gpu jobs
            if any([node.count("g") == 1 for node in nodelist]):
                print(nodelist, jobid)
            return "gpu"
        else:
            # check for gpu nodes being used for cpu jobs
            if any([node.count("g") == 2 for node in nodelist]):
                print(nodelist, jobid)
            return "cpu"

# %%
df["node-type"] = df.apply(lambda row: node_type(row["nodelist-expanded"], row["gpus"], row["jobid"]), axis="columns")

# %%
df["node-type"].value_counts()
# Out:
# node-type
# cpu    764205
# gpu      1220
# Name: count, dtype: int64

# %% [markdown]
# ## Write to JSON

# %%
cols = ["cluster", "start", "end", "elapsedraw", "limit-minutes", "cores", "nodes", "cpu-seconds", "cpu-eff",  "cpu-mem-util", "cpu-mem-alloc", "gpus", "gpu-seconds", "gpu-eff", "gpu-mem-util", "node-type"]
df[cols].to_json("tiger_2023.json")

# %% [markdown]
# ## Definitions

# %% [markdown]
# <pre>end minus start is the run time in seconds (this should equal elapsedraw)
# limit-minutes is the run time limit in minutes
# cpu-seconds is the number of CPU-cores multiplied by elapsedraw
# cpu-eff is the CPU efficiency or CPU utilization (varies from 0-100%)
# cpu-mem-util is the CPU memory utilization (used/allocated); it varies from 0-100%
# cpu-mem-alloc is the total allocated CPU memory in GB for the job
# gpus is the number of GPUs allocated for the job
# gpu-seconds is the number of GPUs multiplied by elapsedraw
# gpu-eff is the GPU efficiency or GPU utilization (varies from 0-100%)
# gpu-mem-util is the GPU memory utilization (varies from 0-100%)</pre>
