# %% [markdown]
# # Cleaning sacct data for Stellar

# %% [markdown]
# <pre>$ ssh stellar
# $ export SLURM_TIME_FORMAT="%s"
# $ sacct -M stellar -a -X -P -S 2023-01-01T00:00:00 -E 2023-12-31T23:59:59 -o cluster,start,end,elapsedraw,timelimitraw,ncpus,nnodes,cputimeraw,alloctres,nodelist,admincomment > stellar.2023</pre>

# %% [markdown]
# ## Working directory

# %% [markdown]
# On della, see /home/jdh4/wentzlaff_job_data_2023

# %% [markdown]
# ## Cleaning

# %%
import os
import re
import subprocess
import numpy as np
import pandas as pd
from efficiency import get_stats_dict
from efficiency import cpu_efficiency
from efficiency import gpu_efficiency
from efficiency import cpu_memory_usage
from efficiency import gpu_memory_usage_eff_tuples

# %%
df = pd.read_csv("stellar.2023", sep="|")
df.head(2).T
# Out:
#                                                               0  \
# Cluster                                                 stellar
# Start                                              1672399940.0
# End                                                  1672573056
# ElapsedRaw                                               173116
# TimelimitRaw                                               2880
# NCPUS                                                      1536
# NNodes                                                       16
# CPUTimeRAW                                            265906176
# AllocTRES              billing=2812,cpu=1536,mem=11250G,node=16
# NodeList                                 stellar-i08n[1-5,7-17]
# AdminComment  JS1:H4sIAIdwsWMC/5WU22rDMAxA/yXPmZF1saT9zChrGI...
#
#                                                               1
# Cluster                                                 stellar
# Start                                              1672573066.0
# End                                                  1672746193
# ElapsedRaw                                               173127
# TimelimitRaw                                               2880
# NCPUS                                                      1536
# NNodes                                                       16
# CPUTimeRAW                                            265923072
# AllocTRES              billing=2812,cpu=1536,mem=11250G,node=16
# NodeList                                 stellar-i08n[1-5,7-17]
# AdminComment  JS1:H4sIANgUtGMC/5WUy2rDMBBF/8VrV8xo3v2ZEhpTAn...

# %%
df.columns = [col.lower() for col in df.columns]

# %%
renamings = {"user":"netid",
             "cputimeraw":"cpu-seconds",
             "nnodes":"nodes",
             "ncpus":"cores",
             "timelimitraw":"limit-minutes"}
df.rename(columns=renamings, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 805503 entries, 0 to 805502
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   cluster        805503 non-null  object
#  1   start          786649 non-null  float64
#  2   end            805503 non-null  int64
#  3   elapsedraw     805503 non-null  int64
#  4   limit-minutes  805503 non-null  int64
#  5   cores          805503 non-null  int64
#  6   nodes          805503 non-null  int64
#  7   cpu-seconds    805503 non-null  int64
#  8   alloctres      785881 non-null  object
#  9   nodelist       805503 non-null  object
#  10  admincomment   786640 non-null  object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 67.6+ MB

# %%
if df["elapsedraw"].dtype == 'object':
    # clean elapsedraw field
    df = df[pd.notna(df.elapsedraw)]
    df = df[df.elapsedraw.str.isnumeric()]
df.elapsedraw = df.elapsedraw.astype("int64")
df = df[df.elapsedraw > 0]

# %%
if df["start"].dtype == 'object':
    # clean start field
    df = df[pd.notna(df.start)]
    df = df[df.start.str.isnumeric()]
df.start = df.start.astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 687625 entries, 0 to 805502
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   cluster        687625 non-null  object
#  1   start          687625 non-null  int64
#  2   end            687625 non-null  int64
#  3   elapsedraw     687625 non-null  int64
#  4   limit-minutes  687625 non-null  int64
#  5   cores          687625 non-null  int64
#  6   nodes          687625 non-null  int64
#  7   cpu-seconds    687625 non-null  int64
#  8   alloctres      687625 non-null  object
#  9   nodelist       687625 non-null  object
#  10  admincomment   687616 non-null  object
# dtypes: int64(7), object(4)
# memory usage: 63.0+ MB

# %%
def gpus_per_job(tres: str) -> int:
    """Return the number of allocated GPUs."""
    gpus = re.findall(r"gres/gpu=\d+", tres)
    return int(gpus[0].replace("gres/gpu=", "")) if gpus else 0

# %%
df["gpus"] = df.alloctres.apply(gpus_per_job)
df["gpu-seconds"] = df.apply(lambda row: row["elapsedraw"] * row["gpus"], axis='columns')

# %%
df["admincomment"] = df["admincomment"].apply(get_stats_dict)

# %% [markdown]
# ## CPU and GPU efficiency

# %%
df["jobid"] = -1

# %%
df["cpu-eff-tuple"] = df.apply(lambda row: cpu_efficiency(row["admincomment"],
                                                          row["elapsedraw"],
                                                          row["jobid"],
                                                          row["cluster"],
                                                          single=True),
                                                          axis="columns")

# %%
def clean_eff_tuple(tpl):
    eff, error_code = tpl
    if error_code:
        return np.nan
    else:
        return eff

# %%
df["cpu-eff"] = df["cpu-eff-tuple"].apply(clean_eff_tuple)

# %%
df["gpu-eff-tuple"] = df.apply(lambda row: gpu_efficiency(row["admincomment"],
                                                          row["elapsedraw"],
                                                          row["jobid"],
                                                          row["cluster"],
                                                          single=True,
                                                          verbose=False),
                                                          axis="columns")

# %%
df["gpu-eff"] = df["gpu-eff-tuple"].apply(clean_eff_tuple)

# %%
df.head(2).T
# Out:
#                                                                0  \
# cluster                                                  stellar
# start                                                 1672399940
# end                                                   1672573056
# elapsedraw                                                173116
# limit-minutes                                               2880
# cores                                                       1536
# nodes                                                         16
# cpu-seconds                                            265906176
# alloctres               billing=2812,cpu=1536,mem=11250G,node=16
# nodelist                                  stellar-i08n[1-5,7-17]
# admincomment   {'nodes': {'stellar-i08n10': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (97.8, 0)
# cpu-eff                                                     97.8
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
#
#                                                                1
# cluster                                                  stellar
# start                                                 1672573066
# end                                                   1672746193
# elapsedraw                                                173127
# limit-minutes                                               2880
# cores                                                       1536
# nodes                                                         16
# cpu-seconds                                            265923072
# alloctres               billing=2812,cpu=1536,mem=11250G,node=16
# nodelist                                  stellar-i08n[1-5,7-17]
# admincomment   {'nodes': {'stellar-i08n10': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (97.9, 0)
# cpu-eff                                                     97.9
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN

# %%
df[["nodes", "cores", "gpus", "cpu-eff", "gpu-eff"]].describe()
# Out:
#                nodes          cores           gpus        cpu-eff  \
# count  687625.000000  687625.000000  687625.000000  269542.000000
# mean        1.665389      89.656233       0.058272      62.850998
# std         5.178620     646.157794       0.246596      30.411529
# min         1.000000       1.000000       0.000000       0.000000
# 25%         1.000000       1.000000       0.000000      39.700000
# 50%         1.000000       1.000000       0.000000      67.300000
# 75%         1.000000       4.000000       0.000000      93.400000
# max       144.000000   18432.000000       4.000000      99.900000
#
#             gpu-eff
# count  31328.000000
# mean      15.053001
# std       27.418795
# min        0.000000
# 25%        0.000000
# 50%        1.400000
# 75%       16.000000
# max      100.000000

# %% [markdown]
# ## CPU and GPU memory

# %%
df["cpu-mem-tuple"] = df.apply(lambda row: cpu_memory_usage(row["admincomment"],
                                                            row["jobid"],
                                                            row["cluster"],
                                                            verbose=False),
                                                            axis="columns")
# Out:
# CPU memory usage > 100%: -1 stellar 87600263168 31457280000
# CPU memory usage > 100%: -1 stellar 55828275200 34359738368
# CPU memory usage > 100%: -1 stellar 44024221696 34359738368
# CPU memory usage > 100%: -1 stellar 1130527821824 1127428915200
# CPU memory usage > 100%: -1 stellar 41761218560 34359738368
# CPU memory usage > 100%: -1 stellar 368970825728 360777252864
# CPU memory usage > 100%: -1 stellar 537174888448 536870912000

# %%
df["gpu-mem-tuple"] = df.apply(lambda row: gpu_memory_usage_eff_tuples(row["admincomment"],
                                                                       row["jobid"],
                                                                       row["cluster"],
                                                                       verbose=False),
                                                                       axis="columns")

# %%
def cpu_mem_util(tpl):
    used, alloc, err = tpl
    if err or alloc == 0:
        return np.nan
    util = round(100 * used / alloc)
    if util > 100:
        return np.nan
    return util


def cpu_mem_alloc(tpl):
    used, alloc, err = tpl
    if err:
        return np.nan
    return alloc

def gpu_mem_util(tpl):
    gpus, err = tpl
    if err:
        return np.nan
    used = 0
    alloc = 0
    for gpu in gpus:
        used += gpu[0]
        alloc += gpu[1]
    return round(100 * used / alloc)

# %%
df["cpu-mem-util"] = df["cpu-mem-tuple"].apply(cpu_mem_util)
df["cpu-mem-alloc"] = df["cpu-mem-tuple"].apply(cpu_mem_alloc)
df["gpu-mem-util"] = df["gpu-mem-tuple"].apply(gpu_mem_util)

# %%
df.head(15).T
# Out:
#                                                               0   \
# cluster                                                  stellar
# start                                                 1672399940
# end                                                   1672573056
# elapsedraw                                                173116
# limit-minutes                                               2880
# cores                                                       1536
# nodes                                                         16
# cpu-seconds                                            265906176
# alloctres               billing=2812,cpu=1536,mem=11250G,node=16
# nodelist                                  stellar-i08n[1-5,7-17]
# admincomment   {'nodes': {'stellar-i08n10': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (97.8, 0)
# cpu-eff                                                     97.8
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                               (2801.0, 11250.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                25.0
# cpu-mem-alloc                                            11250.0
# gpu-mem-util                                                 NaN
#
#                                                               1   \
# cluster                                                  stellar
# start                                                 1672573066
# end                                                   1672746193
# elapsedraw                                                173127
# limit-minutes                                               2880
# cores                                                       1536
# nodes                                                         16
# cpu-seconds                                            265923072
# alloctres               billing=2812,cpu=1536,mem=11250G,node=16
# nodelist                                  stellar-i08n[1-5,7-17]
# admincomment   {'nodes': {'stellar-i08n10': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (97.9, 0)
# cpu-eff                                                     97.9
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                               (2805.0, 11250.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                25.0
# cpu-mem-alloc                                            11250.0
# gpu-mem-util                                                 NaN
#
#                                                               2   \
# cluster                                                  stellar
# start                                                 1672746201
# end                                                   1672919328
# elapsedraw                                                173127
# limit-minutes                                               2880
# cores                                                       1536
# nodes                                                         16
# cpu-seconds                                            265923072
# alloctres               billing=2812,cpu=1536,mem=11250G,node=16
# nodelist                                  stellar-i08n[1-5,7-17]
# admincomment   {'nodes': {'stellar-i08n10': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.0, 0)
# cpu-eff                                                     99.0
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                               (2810.0, 11250.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                25.0
# cpu-mem-alloc                                            11250.0
# gpu-mem-util                                                 NaN
#
#                                                               3   \
# cluster                                                  stellar
# start                                                 1673092206
# end                                                   1673265331
# elapsedraw                                                173125
# limit-minutes                                               2880
# cores                                                       1536
# nodes                                                         16
# cpu-seconds                                            265920000
# alloctres               billing=2812,cpu=1536,mem=11250G,node=16
# nodelist       stellar-k07n[2,4-5,20-21],stellar-k08n[1-8,11-13]
# admincomment   {'nodes': {'stellar-k07n20': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.2, 0)
# cpu-eff                                                     99.2
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                               (2823.0, 11250.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                25.0
# cpu-mem-alloc                                            11250.0
# gpu-mem-util                                                 NaN
#
#                                                               4   \
# cluster                                                  stellar
# start                                                 1672177580
# end                                                   1672782704
# elapsedraw                                                605124
# limit-minutes                                              10080
# cores                                                         16
# nodes                                                          1
# cpu-seconds                                              9681984
# alloctres                      billing=64,cpu=16,mem=256G,node=1
# nodelist                                           stellar-k09n1
# admincomment   {'nodes': {'stellar-k09n1': {'total_memory': 2...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (63.4, 0)
# cpu-eff                                                     63.4
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (71.0, 256.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                28.0
# cpu-mem-alloc                                              256.0
# gpu-mem-util                                                 NaN
#
#                                                               5   \
# cluster                                                  stellar
# start                                                 1672491840
# end                                                   1672596302
# elapsedraw                                                104462
# limit-minutes                                               1800
# cores                                                       1920
# nodes                                                         20
# cpu-seconds                                            200567040
# alloctres                billing=1920,cpu=1920,mem=1920G,node=20
# nodelist                       stellar-i03n21,stellar-i04n[1-19]
# admincomment   {'nodes': {'stellar-i03n21': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (77.8, 0)
# cpu-eff                                                     77.8
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                  (24.0, 1920.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                 1.0
# cpu-mem-alloc                                             1920.0
# gpu-mem-util                                                 NaN
#
#                                                               6   \
# cluster                                                  stellar
# start                                                 1672365636
# end                                                   1672625137
# elapsedraw                                                259501
# limit-minutes                                               4320
# cores                                                         96
# nodes                                                          1
# cpu-seconds                                             24912096
# alloctres                  billing=175,cpu=96,mem=720000M,node=1
# nodelist                                          stellar-i08n19
# admincomment   {'nodes': {'stellar-i08n19': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (66.3, 0)
# cpu-eff                                                     66.3
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                   (23.0, 703.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                 3.0
# cpu-mem-alloc                                              703.0
# gpu-mem-util                                                 NaN
#
#                                                               7   \
# cluster                                                  stellar
# start                                                 1672434522
# end                                                   1672694051
# elapsedraw                                                259529
# limit-minutes                                               4320
# cores                                                        960
# nodes                                                         10
# cpu-seconds                                            249147840
# alloctres                  billing=960,cpu=960,mem=3840G,node=10
# nodelist       stellar-i10n[1-2],stellar-k07n[2,4-5],stellar-...
# admincomment   {'nodes': {'stellar-i10n1': {'total_memory': 4...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.2, 0)
# cpu-eff                                                     99.2
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                (1665.0, 3840.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                43.0
# cpu-mem-alloc                                             3840.0
# gpu-mem-util                                                 NaN
#
#                                                               8   \
# cluster                                                  stellar
# start                                                 1672435269
# end                                                   1672606295
# elapsedraw                                                171026
# limit-minutes                                               2880
# cores                                                        384
# nodes                                                          4
# cpu-seconds                                             65673984
# alloctres                billing=703,cpu=384,mem=2812.50G,node=4
# nodelist                        stellar-m08n21,stellar-m09n[1-3]
# admincomment   {'nodes': {'stellar-m08n21': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.3, 0)
# cpu-eff                                                     99.3
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                 (150.0, 2812.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                 5.0
# cpu-mem-alloc                                             2812.0
# gpu-mem-util                                                 NaN
#
#                                                               9   \
# cluster                                                  stellar
# start                                                 1672436043
# end                                                   1672607051
# elapsedraw                                                171008
# limit-minutes                                               2880
# cores                                                        384
# nodes                                                          4
# cpu-seconds                                             65667072
# alloctres                billing=703,cpu=384,mem=2812.50G,node=4
# nodelist                                     stellar-m09n[14-17]
# admincomment   {'nodes': {'stellar-m09n14': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.4, 0)
# cpu-eff                                                     99.4
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                  (92.0, 2812.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                 3.0
# cpu-mem-alloc                                             2812.0
# gpu-mem-util                                                 NaN
#
#                                                               10  \
# cluster                                                  stellar
# start                                                 1672436076
# end                                                   1672607085
# elapsedraw                                                171009
# limit-minutes                                               2880
# cores                                                        384
# nodes                                                          4
# cpu-seconds                                             65667456
# alloctres                billing=703,cpu=384,mem=2812.50G,node=4
# nodelist                                       stellar-i07n[1-4]
# admincomment   {'nodes': {'stellar-i07n1': {'total_memory': 7...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.4, 0)
# cpu-eff                                                     99.4
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                  (92.0, 2812.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                 3.0
# cpu-mem-alloc                                             2812.0
# gpu-mem-util                                                 NaN
#
#                                                               11  \
# cluster                                                  stellar
# start                                                 1672436114
# end                                                   1672607132
# elapsedraw                                                171018
# limit-minutes                                               2880
# cores                                                        384
# nodes                                                          4
# cpu-seconds                                             65670912
# alloctres                billing=703,cpu=384,mem=2812.50G,node=4
# nodelist                                       stellar-i07n[5-8]
# admincomment   {'nodes': {'stellar-i07n5': {'total_memory': 7...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.4, 0)
# cpu-eff                                                     99.4
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                  (95.0, 2812.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                 3.0
# cpu-mem-alloc                                             2812.0
# gpu-mem-util                                                 NaN
#
#                                                               12  \
# cluster                                                  stellar
# start                                                 1672437011
# end                                                   1672694424
# elapsedraw                                                257413
# limit-minutes                                               4320
# cores                                                        384
# nodes                                                          4
# cpu-seconds                                             98846592
# alloctres                billing=703,cpu=384,mem=2812.50G,node=4
# nodelist                                      stellar-i07n[9-12]
# admincomment   {'nodes': {'stellar-i07n10': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.2, 0)
# cpu-eff                                                     99.2
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                 (150.0, 2812.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                 5.0
# cpu-mem-alloc                                             2812.0
# gpu-mem-util                                                 NaN
#
#                                                               13  \
# cluster                                                  stellar
# start                                                 1672437037
# end                                                   1672694445
# elapsedraw                                                257408
# limit-minutes                                               4320
# cores                                                        384
# nodes                                                          4
# cpu-seconds                                             98844672
# alloctres                billing=703,cpu=384,mem=2812.50G,node=4
# nodelist                                     stellar-i07n[13-16]
# admincomment   {'nodes': {'stellar-i07n13': {'total_memory': ...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.2, 0)
# cpu-eff                                                     99.2
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                 (148.0, 2812.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                 5.0
# cpu-mem-alloc                                             2812.0
# gpu-mem-util                                                 NaN
#
#                                                               14
# cluster                                                  stellar
# start                                                 1672457911
# end                                                   1672717423
# elapsedraw                                                259512
# limit-minutes                                               4320
# cores                                                        960
# nodes                                                         10
# cpu-seconds                                            249131520
# alloctres                  billing=960,cpu=960,mem=3840G,node=10
# nodelist                        stellar-k07n1,stellar-k08n[7-15]
# admincomment   {'nodes': {'stellar-k07n1': {'total_memory': 4...
# gpus                                                           0
# gpu-seconds                                                    0
# jobid                                                         -1
# cpu-eff-tuple                                          (99.2, 0)
# cpu-eff                                                     99.2
# gpu-eff-tuple                                            (-1, 1)
# gpu-eff                                                      NaN
# cpu-mem-tuple                                (1664.0, 3840.0, 0)
# gpu-mem-tuple                                            ([], 1)
# cpu-mem-util                                                43.0
# cpu-mem-alloc                                             3840.0
# gpu-mem-util                                                 NaN

# %%
 df[["cpu-eff",  "cpu-mem-util", "cpu-mem-alloc", "gpus", "gpu-seconds", "gpu-eff", "gpu-mem-util"]].describe()
# Out:
#              cpu-eff   cpu-mem-util  cpu-mem-alloc           gpus  \
# count  269542.000000  269471.000000  269542.000000  687625.000000
# mean       62.850998      16.907745    1035.791042       0.058272
# std        30.411529      26.192279    4253.584018       0.246596
# min         0.000000       0.000000       0.000000       0.000000
# 25%        39.700000       0.000000      16.000000       0.000000
# 50%        67.300000       6.000000      16.000000       0.000000
# 75%        93.400000      17.000000     703.000000       0.000000
# max        99.900000     100.000000   72000.000000       4.000000
#
#          gpu-seconds       gpu-eff  gpu-mem-util
# count  687625.000000  31328.000000  31328.000000
# mean      160.266311     15.053001     73.012130
# std      4788.305164     27.418795     31.424176
# min         0.000000      0.000000      1.000000
# 25%         0.000000      0.000000     42.000000
# 50%         0.000000      1.400000     92.000000
# 75%         0.000000     16.000000     92.000000
# max    656678.000000    100.000000    100.000000

# %%
df["cpu-seconds"].sum() / 3600
# Out:
# 262750797.77222222

# %%
df["gpu-seconds"].sum() / 3600
# Out:
# 30611.978333333333

# %% [markdown]
# ## Node type

# %%
def expand_nodelist(nodes: int, nodelist: str) -> list:
    """Convert a nodelist from sacct to a Python list of node names. For
       example: della-l07g[4-7],della-l08g2 becomes
       ['della-l07g4', 'della-l07g5', 'della-l07g6', 'della-l07g7', 'della-l08g2']
    """
    if nodes == 1:
        return [nodelist]
    cmd = f"scontrol show hostname {nodelist}"
    try:
        output = subprocess.run(cmd,
                                stdout=subprocess.PIPE,
                                shell=True,
                                timeout=5,
                                text=True,
                                check=True)
    except:
        print(f"Failed to get nodes for {nodelist}")
    else:
        return output.stdout.strip().split("\n")

# %%
df["nodelist-expanded"] = df.apply(lambda row: expand_nodelist(row["nodes"], row["nodelist"]), axis="columns")

# %%
amd =  [f"stellar-m01n{j}" for j in range(1, 21)]
amd += [f"stellar-m0{i}n{j}" for i in [2, 3] for j in range(1, 35)]
amd += [f"stellar-m04n{j}" for j in range(1, 33)]
amd += [f"stellar-m05n{j}" for j in range(1, 34)]
amd += [f"stellar-m06n{j}" for j in range(1, 35)]
amd = set(amd)

# %%
print(len(amd))
# Out:
# 187

# %%
def node_type(nodelist, gpus, jobid):
    if nodelist == ["stellar-bigmem"]:
        return "bigmem"
    elif gpus > 0:
        return "gpu"
    elif any([nodelist == [f"stellar-m01g{i}"] for i in range(1, 7)]):
        # alloctres was missing gres/gpu for these jobs
        return "gpu"
    else:
        sub = set(nodelist) - amd
        if len(sub) < len(nodelist):
            # check for intel nodes being used for amd jobs
            if "k" in "".join(nodelist):
                print(nodelist, jobid)
            return "amd"
        else:
            # check for amd nodes being used for intel jobs
            if any([f"m0{i}" in "".join(nodelist) for i in range(1, 7)]):
                print(nodelist, jobid)
            return "intel"

# %%
df["node-type"] = df.apply(lambda row: node_type(row["nodelist-expanded"], row["gpus"], row["jobid"]), axis="columns")

# %%
df["node-type"].value_counts()
# Out:
# node-type
# amd       487500
# intel     160651
# gpu        38442
# bigmem      1032
# Name: count, dtype: int64

# %% [markdown]
# ## Write to JSON

# %%
cols = ["cluster", "start", "end", "elapsedraw", "limit-minutes", "cores", "nodes", "cpu-seconds", "cpu-eff",  "cpu-mem-util", "cpu-mem-alloc", "gpus", "gpu-seconds", "gpu-eff", "gpu-mem-util", "node-type"]
df[cols].to_json("stellar_2023.json")

# %% [markdown]
# ## Definitions

# %% [markdown]
# <pre>end minus start is the run time in seconds (this should equal elapsedraw)
# limit-minutes is the run time limit in minutes
# cpu-seconds is the number of CPU-cores multiplied by elapsedraw
# cpu-eff is the CPU efficiency or CPU utilization (varies from 0-100%)
# cpu-mem-util is the CPU memory utilization (used/allocated); it varies from 0-100%
# cpu-mem-alloc is the total allocated CPU memory in GB for the job
# gpus is the number of GPUs allocated for the job
# gpu-seconds is the number of GPUs multiplied by elapsedraw
# gpu-eff is the GPU efficiency or GPU utilization (varies from 0-100%)
# gpu-mem-util is the GPU memory utilization (varies from 0-100%)</pre>
